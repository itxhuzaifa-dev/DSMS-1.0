# %%
# 1. What do you mean by __name__ == '__main__'

# %% [markdown]
# ### What is a module?
#
# Any file with an extention of .py is called a module in python.
#
# Whenever we execute a program it's module name is `__main__` and this name is stored in `__name__` variable

# %%
def display():
  print('hello')

display()
print(__name__) # whenever we print __name__ we will get __main__ in any file
# Out:
# hello
# __main__

# %% [markdown]
# Python always considers currently executing file as __main__.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## So from above code we can see:
#
# if we print __name__ in the current file than it will show __main__.
# But if we import a file and then write filename.__name__ then it will show that file name.
#
# Module1 is running in current file with its original name
#
#
# ### So, if a file is running in its own file than it runs as __main__ but same file in another file is used by its original name.

# %% [markdown]
# # Important Observation
#
# Lets module1 file contains this code :
#
#
# ![image.png](data:image/png;base64,...)
#
#
# And module2 file contains this code:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now we run the module2.py than we get output as :
#
# (It will also show the square of number from 1 to 11. Code written in module1.py)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Reason:
#
# This is showing result of module1 also because we are importing module1.py in module2.py. So import module1 line is equivalent to whole code written in module1.py. It means while importing code of first file will come on top of current file.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Prevention:
#
# We can use __ name __=__ main __ to prevent first file unnecessary code to be import in second file.
#
# ![image.png](data:image/png;base64,...)
#
# Now this code will run in its file only.

# %% [markdown]
# Now it will show only desired result.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## If we want to give access of private code to second file.
#
# We will change module1.py as below:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Then we can print the output of restricted code in second file as well.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## New Output:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## So now we have now 3 options:
#
# 1) If we want some code to be imported in another file, we will write it in top
#
# 2) If we want some code not to be use by other file, then we will write it using __ name __=__ main __
#
# 3) If we want other programmers to use some code in some scenario then we write it in main function.

# %% [markdown]
# # Importing a module
#
# - But what is the need to import a module?
# - How to import a module

# %% [markdown]
# ### 1) But what is the need to import a module?
#
# - Code Modularity
# - Code Reuseability

# %% [markdown]
# ### 2) Import a module

# %%
import test
test.hello('Deepa')
# Out:
# Hello Deepa

# %%
# import multiple module -> user defined + builtin
import math
import test

test.hello('Deepa')
print(math.floor(4.3))
# Out:
# Hello Deepa
# 4

# %% [markdown]
# ### Variations of import statement

# %%
# Normal
import math
import random

# %%
# clubbing together
import math,random,test

# %%
# importing specific names from module
from math import factorial,floor
from test import hello

print(factorial(5))
ceil(4.8)  # we are not importing everything from math module here
# Out:
# 120
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cbe7c40736a8> in <module>
#       4
#       5 print(factorial(5))
# ----> 6 ceil(4.8)
#
# NameError: name 'ceil' is not defined

# %%
# renaming modules
import math as m
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


m.factorial(5)
# Out:
# 120

# %%
from math import factorial as f

f(5)
# Out:
# 120

# %% [markdown]
# ### Order of execution of a module

# %%
import sys
for p in sys.path:
  print(p)
# Out:
# /content
# /env/python
# /usr/lib/python38.zip
# /usr/lib/python3.8
# /usr/lib/python3.8/lib-dynload
#
# /usr/local/lib/python3.8/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.8/dist-packages/IPython/extensions
# /root/.ipython

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### What are packages in Python
#
# A package in python is a directory containing similar sub packages and modules.
#
# - A particular directory is treated as package if it has `__init__.py` file in it.
# - The `__init__.py` file may be empty or contain some initialization code related to the package

# %% [markdown]
# ### What are 3rd party packages?
#
# - The python community creates packages and make it available for other programmers
# - PyPI -> Python Package Index
# - You can upload your own package
# - You can also install packages from PyPI and install using pip
# - pip is a package manager utility
# - it is automatically installed with python
