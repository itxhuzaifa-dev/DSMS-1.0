# %% [markdown]
# # Data Gathering Process

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
pd.read_excel('output.xlsx',index_col='Unnamed: 0')
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4       A Dananjaya             4
# ..              ...           ...
# 511     YV Takawale           192
# 512   Yashpal Singh            47
# 513     Younis Khan             3
# 514    Yuvraj Singh          2765
# 515          Z Khan           117
#
# [516 rows x 2 columns]

# %%
# reading an excel file present in another sheet of ms excel
pd.read_excel('output.xlsx',sheet_name='Sheet_name_2')
# Out:
#             batsman  Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# 0    A Ashish Reddy                 45.0              NaN             NaN
# 1        A Chandila                  NaN              0.0             NaN
# 2          A Chopra                  NaN             35.0             NaN
# 3       A Choudhary                  NaN              NaN             NaN
# 4       A Dananjaya                  NaN              NaN             NaN
# ..              ...                  ...              ...             ...
# 511     YV Takawale                 19.0              5.0             NaN
# 512   Yashpal Singh                  NaN              NaN             NaN
# 513     Younis Khan                  NaN              NaN             NaN
# 514    Yuvraj Singh                345.0            118.0            59.0
# 515          Z Khan                 39.0              4.0             NaN
#
#      Delhi Daredevils  Gujarat Lions  Kings XI Punjab  Kochi Tuskers Kerala  \
# ...

# %% [markdown]
# ### Reading text files

# %% [markdown]
# ### Parser error because no comma separated data
# ![image.png](attachment:image.png)

# %%
pd.read_csv('question_answer_pairs.txt',sep='\t')
# Out:
#          ArticleTitle                                           Question  \
# 0     Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...
# 1     Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...
# 2     Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...
# 3     Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...
# 4     Abraham_Lincoln                   Did his mother die of pneumonia?
# ...               ...                                                ...
# 1710   Woodrow_Wilson  Was Wilson president of the American Political...
# 1711   Woodrow_Wilson  Did he not cast his ballot for John M. Palmer ...
# 1712   Woodrow_Wilson  Did Wilson not spend 1914 through the beginnin...
# 1713   Woodrow_Wilson  Was Wilson , a staunch opponent of antisemitis...
# 1714   Woodrow_Wilson                             What happened in 1917?
#
#                                                  Answer  \
# ...
